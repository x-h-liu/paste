# %%
import sys
sys.path.insert(0, '/n/fs/ragr-research/users/xinhao/workspace/code/paste')


import scanpy as sc

from src.paste.fractional_model_selection import decide_overlap, decide_overlap_plotting

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Out:
# hello

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta0.1_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta0.1_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=2.0216E+7
# Iteration: 1 | deviance=2.0214E+7
# Iteration: 2 | deviance=1.8184E+7
# Iteration: 3 | deviance=1.7635E+7
# Iteration: 4 | deviance=1.7398E+7
# Iteration: 5 | deviance=1.7294E+7
# Iteration: 6 | deviance=1.7238E+7
# Iteration: 7 | deviance=1.7202E+7
# Iteration: 8 | deviance=1.7176E+7
# Iteration: 9 | deviance=1.7157E+7
# Iteration: 10 | deviance=1.7142E+7
# Iteration: 11 | deviance=1.7130E+7
# Iteration: 12 | deviance=1.7120E+7
# Iteration: 13 | deviance=1.7112E+7
# Iteration: 14 | deviance=1.7106E+7
# Iteration: 15 | deviance=1.7100E+7
# Iteration: 16 | deviance=1.7096E+7
# Iteration: 17 | deviance=1.7091E+7
# Iteration: 18 | deviance=1.7088E+7
# Iteration: 19 | deviance=1.7085E+7
# Iteration: 20 | deviance=1.7082E+7
# Iteration: 21 | deviance=1.7079E+7
# Iteration: 22 | deviance=1.7077E+7
# Iteration: 23 | deviance=1.7075E+7
# Iteration: 24 | deviance=1.7073E+7
# GLM-PCA finished with joint matrix shape (6903, 50)
# 0.9

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta1.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta1.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.7198E+7
# Iteration: 1 | deviance=1.7195E+7
# Iteration: 2 | deviance=1.5331E+7
# Iteration: 3 | deviance=1.4935E+7
# Iteration: 4 | deviance=1.4737E+7
# Iteration: 5 | deviance=1.4635E+7
# Iteration: 6 | deviance=1.4578E+7
# Iteration: 7 | deviance=1.4543E+7
# Iteration: 8 | deviance=1.4518E+7
# Iteration: 9 | deviance=1.4500E+7
# Iteration: 10 | deviance=1.4487E+7
# Iteration: 11 | deviance=1.4477E+7
# Iteration: 12 | deviance=1.4468E+7
# Iteration: 13 | deviance=1.4461E+7
# Iteration: 14 | deviance=1.4455E+7
# Iteration: 15 | deviance=1.4450E+7
# Iteration: 16 | deviance=1.4446E+7
# Iteration: 17 | deviance=1.4442E+7
# Iteration: 18 | deviance=1.4439E+7
# Iteration: 19 | deviance=1.4436E+7
# Iteration: 20 | deviance=1.4433E+7
# Iteration: 21 | deviance=1.4431E+7
# Iteration: 22 | deviance=1.4429E+7
# Iteration: 23 | deviance=1.4427E+7
# Iteration: 24 | deviance=1.4426E+7
# Iteration: 25 | deviance=1.4424E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta2.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta2.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.7078E+7
# Iteration: 1 | deviance=1.7074E+7
# Iteration: 2 | deviance=1.4834E+7
# Iteration: 3 | deviance=1.4466E+7
# Iteration: 4 | deviance=1.4298E+7
# Iteration: 5 | deviance=1.4204E+7
# Iteration: 6 | deviance=1.4146E+7
# Iteration: 7 | deviance=1.4110E+7
# Iteration: 8 | deviance=1.4086E+7
# Iteration: 9 | deviance=1.4069E+7
# Iteration: 10 | deviance=1.4056E+7
# Iteration: 11 | deviance=1.4046E+7
# Iteration: 12 | deviance=1.4037E+7
# Iteration: 13 | deviance=1.4030E+7
# Iteration: 14 | deviance=1.4024E+7
# Iteration: 15 | deviance=1.4019E+7
# Iteration: 16 | deviance=1.4015E+7
# Iteration: 17 | deviance=1.4011E+7
# Iteration: 18 | deviance=1.4008E+7
# Iteration: 19 | deviance=1.4005E+7
# Iteration: 20 | deviance=1.4002E+7
# Iteration: 21 | deviance=1.4000E+7
# Iteration: 22 | deviance=1.3998E+7
# Iteration: 23 | deviance=1.3996E+7
# Iteration: 24 | deviance=1.3994E+7
# Iteration: 25 | deviance=1.3993E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta3.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.9_dropFalse_rotateFalse_resampleTrue_delta3.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.7162E+7
# Iteration: 1 | deviance=1.7158E+7
# Iteration: 2 | deviance=1.4686E+7
# Iteration: 3 | deviance=1.4317E+7
# Iteration: 4 | deviance=1.4138E+7
# Iteration: 5 | deviance=1.4035E+7
# Iteration: 6 | deviance=1.3977E+7
# Iteration: 7 | deviance=1.3940E+7
# Iteration: 8 | deviance=1.3915E+7
# Iteration: 9 | deviance=1.3897E+7
# Iteration: 10 | deviance=1.3884E+7
# Iteration: 11 | deviance=1.3873E+7
# Iteration: 12 | deviance=1.3865E+7
# Iteration: 13 | deviance=1.3858E+7
# Iteration: 14 | deviance=1.3853E+7
# Iteration: 15 | deviance=1.3848E+7
# Iteration: 16 | deviance=1.3844E+7
# Iteration: 17 | deviance=1.3840E+7
# Iteration: 18 | deviance=1.3837E+7
# Iteration: 19 | deviance=1.3834E+7
# Iteration: 20 | deviance=1.3832E+7
# Iteration: 21 | deviance=1.3830E+7
# Iteration: 22 | deviance=1.3828E+7
# Iteration: 23 | deviance=1.3826E+7
# Iteration: 24 | deviance=1.3825E+7
# Iteration: 25 | deviance=1.3823E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta0.1_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta0.1_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.6949E+7
# Iteration: 1 | deviance=1.6947E+7
# Iteration: 2 | deviance=1.5353E+7
# Iteration: 3 | deviance=1.4888E+7
# Iteration: 4 | deviance=1.4689E+7
# Iteration: 5 | deviance=1.4598E+7
# Iteration: 6 | deviance=1.4546E+7
# Iteration: 7 | deviance=1.4513E+7
# Iteration: 8 | deviance=1.4488E+7
# Iteration: 9 | deviance=1.4471E+7
# Iteration: 10 | deviance=1.4457E+7
# Iteration: 11 | deviance=1.4446E+7
# Iteration: 12 | deviance=1.4437E+7
# Iteration: 13 | deviance=1.4430E+7
# Iteration: 14 | deviance=1.4423E+7
# Iteration: 15 | deviance=1.4418E+7
# Iteration: 16 | deviance=1.4414E+7
# Iteration: 17 | deviance=1.4410E+7
# Iteration: 18 | deviance=1.4407E+7
# Iteration: 19 | deviance=1.4404E+7
# Iteration: 20 | deviance=1.4401E+7
# Iteration: 21 | deviance=1.4399E+7
# Iteration: 22 | deviance=1.4397E+7
# Iteration: 23 | deviance=1.4395E+7
# Iteration: 24 | deviance=1.4393E+7
# Iteration: 25 | deviance=1.4391E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta1.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta1.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.4385E+7
# Iteration: 1 | deviance=1.4383E+7
# Iteration: 2 | deviance=1.2938E+7
# Iteration: 3 | deviance=1.2591E+7
# Iteration: 4 | deviance=1.2434E+7
# Iteration: 5 | deviance=1.2351E+7
# Iteration: 6 | deviance=1.2305E+7
# Iteration: 7 | deviance=1.2276E+7
# Iteration: 8 | deviance=1.2257E+7
# Iteration: 9 | deviance=1.2242E+7
# Iteration: 10 | deviance=1.2231E+7
# Iteration: 11 | deviance=1.2222E+7
# Iteration: 12 | deviance=1.2215E+7
# Iteration: 13 | deviance=1.2209E+7
# Iteration: 14 | deviance=1.2204E+7
# Iteration: 15 | deviance=1.2200E+7
# Iteration: 16 | deviance=1.2196E+7
# Iteration: 17 | deviance=1.2193E+7
# Iteration: 18 | deviance=1.2190E+7
# Iteration: 19 | deviance=1.2188E+7
# Iteration: 20 | deviance=1.2185E+7
# Iteration: 21 | deviance=1.2183E+7
# Iteration: 22 | deviance=1.2182E+7
# Iteration: 23 | deviance=1.2180E+7
# Iteration: 24 | deviance=1.2179E+7
# Iteration: 25 | deviance=1.2177E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta2.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta2.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.4278E+7
# Iteration: 1 | deviance=1.4276E+7
# Iteration: 2 | deviance=1.2574E+7
# Iteration: 3 | deviance=1.2240E+7
# Iteration: 4 | deviance=1.2082E+7
# Iteration: 5 | deviance=1.1986E+7
# Iteration: 6 | deviance=1.1930E+7
# Iteration: 7 | deviance=1.1895E+7
# Iteration: 8 | deviance=1.1873E+7
# Iteration: 9 | deviance=1.1857E+7
# Iteration: 10 | deviance=1.1846E+7
# Iteration: 11 | deviance=1.1837E+7
# Iteration: 12 | deviance=1.1829E+7
# Iteration: 13 | deviance=1.1823E+7
# Iteration: 14 | deviance=1.1818E+7
# Iteration: 15 | deviance=1.1814E+7
# Iteration: 16 | deviance=1.1810E+7
# Iteration: 17 | deviance=1.1807E+7
# Iteration: 18 | deviance=1.1805E+7
# Iteration: 19 | deviance=1.1802E+7
# Iteration: 20 | deviance=1.1800E+7
# Iteration: 21 | deviance=1.1798E+7
# Iteration: 22 | deviance=1.1797E+7
# Iteration: 23 | deviance=1.1795E+7
# Iteration: 24 | deviance=1.1794E+7
# Iteration: 25 | deviance=1.1793E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta3.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.7_dropFalse_rotateFalse_resampleTrue_delta3.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.4349E+7
# Iteration: 1 | deviance=1.4346E+7
# Iteration: 2 | deviance=1.2349E+7
# Iteration: 3 | deviance=1.2052E+7
# Iteration: 4 | deviance=1.1913E+7
# Iteration: 5 | deviance=1.1831E+7
# Iteration: 6 | deviance=1.1783E+7
# Iteration: 7 | deviance=1.1752E+7
# Iteration: 8 | deviance=1.1732E+7
# Iteration: 9 | deviance=1.1718E+7
# Iteration: 10 | deviance=1.1707E+7
# Iteration: 11 | deviance=1.1699E+7
# Iteration: 12 | deviance=1.1692E+7
# Iteration: 13 | deviance=1.1686E+7
# Iteration: 14 | deviance=1.1681E+7
# Iteration: 15 | deviance=1.1677E+7
# Iteration: 16 | deviance=1.1674E+7
# Iteration: 17 | deviance=1.1671E+7
# Iteration: 18 | deviance=1.1668E+7
# Iteration: 19 | deviance=1.1666E+7
# Iteration: 20 | deviance=1.1664E+7
# Iteration: 21 | deviance=1.1662E+7
# Iteration: 22 | deviance=1.1661E+7
# Iteration: 23 | deviance=1.1659E+7
# Iteration: 24 | deviance=1.1658E+7
# Iteration: 25 | deviance=1.1657E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta0.1_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta0.1_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.4411E+7
# Iteration: 1 | deviance=1.4410E+7
# Iteration: 2 | deviance=1.3145E+7
# Iteration: 3 | deviance=1.2758E+7
# Iteration: 4 | deviance=1.2592E+7
# Iteration: 5 | deviance=1.2501E+7
# Iteration: 6 | deviance=1.2444E+7
# Iteration: 7 | deviance=1.2408E+7
# Iteration: 8 | deviance=1.2383E+7
# Iteration: 9 | deviance=1.2365E+7
# Iteration: 10 | deviance=1.2351E+7
# Iteration: 11 | deviance=1.2339E+7
# Iteration: 12 | deviance=1.2330E+7
# Iteration: 13 | deviance=1.2323E+7
# Iteration: 14 | deviance=1.2316E+7
# Iteration: 15 | deviance=1.2311E+7
# Iteration: 16 | deviance=1.2306E+7
# Iteration: 17 | deviance=1.2302E+7
# Iteration: 18 | deviance=1.2298E+7
# Iteration: 19 | deviance=1.2295E+7
# Iteration: 20 | deviance=1.2292E+7
# Iteration: 21 | deviance=1.2289E+7
# Iteration: 22 | deviance=1.2287E+7
# Iteration: 23 | deviance=1.2285E+7
# Iteration: 24 | deviance=1.2283E+7
# Iteration: 25 | deviance=1.2281E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta1.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta1.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2182E+7
# Iteration: 1 | deviance=1.2180E+7
# Iteration: 2 | deviance=1.1078E+7
# Iteration: 3 | deviance=1.0794E+7
# Iteration: 4 | deviance=1.0640E+7
# Iteration: 5 | deviance=1.0553E+7
# Iteration: 6 | deviance=1.0504E+7
# Iteration: 7 | deviance=1.0473E+7
# Iteration: 8 | deviance=1.0452E+7
# Iteration: 9 | deviance=1.0437E+7
# Iteration: 10 | deviance=1.0425E+7
# Iteration: 11 | deviance=1.0416E+7
# Iteration: 12 | deviance=1.0409E+7
# Iteration: 13 | deviance=1.0403E+7
# Iteration: 14 | deviance=1.0397E+7
# Iteration: 15 | deviance=1.0393E+7
# Iteration: 16 | deviance=1.0389E+7
# Iteration: 17 | deviance=1.0386E+7
# Iteration: 18 | deviance=1.0383E+7
# Iteration: 19 | deviance=1.0381E+7
# Iteration: 20 | deviance=1.0379E+7
# Iteration: 21 | deviance=1.0377E+7
# Iteration: 22 | deviance=1.0375E+7
# Iteration: 23 | deviance=1.0374E+7
# Iteration: 24 | deviance=1.0372E+7
# Iteration: 25 | deviance=1.0371E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta2.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta2.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2072E+7
# Iteration: 1 | deviance=1.2070E+7
# Iteration: 2 | deviance=1.0664E+7
# Iteration: 3 | deviance=1.0393E+7
# Iteration: 4 | deviance=1.0254E+7
# Iteration: 5 | deviance=1.0182E+7
# Iteration: 6 | deviance=1.0144E+7
# Iteration: 7 | deviance=1.0123E+7
# Iteration: 8 | deviance=1.0108E+7
# Iteration: 9 | deviance=1.0097E+7
# Iteration: 10 | deviance=1.0089E+7
# Iteration: 11 | deviance=1.0082E+7
# Iteration: 12 | deviance=1.0077E+7
# Iteration: 13 | deviance=1.0072E+7
# Iteration: 14 | deviance=1.0069E+7
# Iteration: 15 | deviance=1.0065E+7
# Iteration: 16 | deviance=1.0063E+7
# Iteration: 17 | deviance=1.0060E+7
# Iteration: 18 | deviance=1.0058E+7
# Iteration: 19 | deviance=1.0056E+7
# Iteration: 20 | deviance=1.0055E+7
# Iteration: 21 | deviance=1.0053E+7
# Iteration: 22 | deviance=1.0052E+7
# Iteration: 23 | deviance=1.0050E+7
# Iteration: 24 | deviance=1.0049E+7
# Iteration: 25 | deviance=1.0048E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta3.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.5_dropFalse_rotateFalse_resampleTrue_delta3.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2143E+7
# Iteration: 1 | deviance=1.2141E+7
# Iteration: 2 | deviance=1.0594E+7
# Iteration: 3 | deviance=1.0332E+7
# Iteration: 4 | deviance=1.0182E+7
# Iteration: 5 | deviance=1.0091E+7
# Iteration: 6 | deviance=1.0043E+7
# Iteration: 7 | deviance=1.0013E+7
# Iteration: 8 | deviance=9.9940E+6
# Iteration: 9 | deviance=9.9809E+6
# Iteration: 10 | deviance=9.9712E+6
# Iteration: 11 | deviance=9.9638E+6
# Iteration: 12 | deviance=9.9578E+6
# Iteration: 13 | deviance=9.9530E+6
# Iteration: 14 | deviance=9.9489E+6
# Iteration: 15 | deviance=9.9455E+6
# Iteration: 16 | deviance=9.9426E+6
# Iteration: 17 | deviance=9.9401E+6
# Iteration: 18 | deviance=9.9379E+6
# Iteration: 19 | deviance=9.9360E+6
# Iteration: 20 | deviance=9.9343E+6
# Iteration: 21 | deviance=9.9328E+6
# Iteration: 22 | deviance=9.9315E+6
# Iteration: 23 | deviance=9.9303E+6
# Iteration: 24 | deviance=9.9293E+6
# GLM-PCA finished with joint matrix shape (4975, 50)
# 0.99
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta0.1_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta0.1_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2558E+7
# Iteration: 1 | deviance=1.2557E+7
# Iteration: 2 | deviance=1.1403E+7
# Iteration: 3 | deviance=1.1071E+7
# Iteration: 4 | deviance=1.0924E+7
# Iteration: 5 | deviance=1.0845E+7
# Iteration: 6 | deviance=1.0800E+7
# Iteration: 7 | deviance=1.0771E+7
# Iteration: 8 | deviance=1.0751E+7
# Iteration: 9 | deviance=1.0735E+7
# Iteration: 10 | deviance=1.0723E+7
# Iteration: 11 | deviance=1.0713E+7
# Iteration: 12 | deviance=1.0705E+7
# Iteration: 13 | deviance=1.0698E+7
# Iteration: 14 | deviance=1.0692E+7
# Iteration: 15 | deviance=1.0687E+7
# Iteration: 16 | deviance=1.0682E+7
# Iteration: 17 | deviance=1.0678E+7
# Iteration: 18 | deviance=1.0675E+7
# Iteration: 19 | deviance=1.0672E+7
# Iteration: 20 | deviance=1.0669E+7
# Iteration: 21 | deviance=1.0667E+7
# Iteration: 22 | deviance=1.0665E+7
# Iteration: 23 | deviance=1.0663E+7
# Iteration: 24 | deviance=1.0661E+7
# Iteration: 25 | deviance=1.0659E+7
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta1.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta1.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.0571E+7
# Iteration: 1 | deviance=1.0569E+7
# Iteration: 2 | deviance=9.6243E+6
# Iteration: 3 | deviance=9.3586E+6
# Iteration: 4 | deviance=9.2135E+6
# Iteration: 5 | deviance=9.1369E+6
# Iteration: 6 | deviance=9.0953E+6
# Iteration: 7 | deviance=9.0696E+6
# Iteration: 8 | deviance=9.0525E+6
# Iteration: 9 | deviance=9.0402E+6
# Iteration: 10 | deviance=9.0311E+6
# Iteration: 11 | deviance=9.0240E+6
# Iteration: 12 | deviance=9.0183E+6
# Iteration: 13 | deviance=9.0137E+6
# Iteration: 14 | deviance=9.0099E+6
# Iteration: 15 | deviance=9.0068E+6
# Iteration: 16 | deviance=9.0041E+6
# Iteration: 17 | deviance=9.0018E+6
# Iteration: 18 | deviance=8.9999E+6
# Iteration: 19 | deviance=8.9982E+6
# Iteration: 20 | deviance=8.9967E+6
# Iteration: 21 | deviance=8.9954E+6
# Iteration: 22 | deviance=8.9942E+6
# Iteration: 23 | deviance=8.9932E+6
# Iteration: 24 | deviance=8.9923E+6
# GLM-PCA finished with joint matrix shape (4334, 50)
# 0.99
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta2.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta2.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.0481E+7
# Iteration: 1 | deviance=1.0479E+7
# Iteration: 2 | deviance=9.3151E+6
# Iteration: 3 | deviance=9.0709E+6
# Iteration: 4 | deviance=8.9410E+6
# Iteration: 5 | deviance=8.8684E+6
# Iteration: 6 | deviance=8.8293E+6
# Iteration: 7 | deviance=8.8049E+6
# Iteration: 8 | deviance=8.7884E+6
# Iteration: 9 | deviance=8.7768E+6
# Iteration: 10 | deviance=8.7680E+6
# Iteration: 11 | deviance=8.7611E+6
# Iteration: 12 | deviance=8.7556E+6
# Iteration: 13 | deviance=8.7510E+6
# Iteration: 14 | deviance=8.7471E+6
# Iteration: 15 | deviance=8.7439E+6
# Iteration: 16 | deviance=8.7411E+6
# Iteration: 17 | deviance=8.7386E+6
# Iteration: 18 | deviance=8.7365E+6
# Iteration: 19 | deviance=8.7347E+6
# Iteration: 20 | deviance=8.7330E+6
# Iteration: 21 | deviance=8.7315E+6
# Iteration: 22 | deviance=8.7302E+6
# Iteration: 23 | deviance=8.7290E+6
# Iteration: 24 | deviance=8.7279E+6
# Iteration: 25 | deviance=8.7270E+6
# ...

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta3.0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/single_resample/151674_overlap0.3_dropFalse_rotateFalse_resampleTrue_delta3.0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)

print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.0526E+7
# Iteration: 1 | deviance=1.0525E+7
# Iteration: 2 | deviance=9.1899E+6
# Iteration: 3 | deviance=8.9347E+6
# Iteration: 4 | deviance=8.8034E+6
# Iteration: 5 | deviance=8.7387E+6
# Iteration: 6 | deviance=8.7038E+6
# Iteration: 7 | deviance=8.6831E+6
# Iteration: 8 | deviance=8.6693E+6
# Iteration: 9 | deviance=8.6595E+6
# Iteration: 10 | deviance=8.6519E+6
# Iteration: 11 | deviance=8.6460E+6
# Iteration: 12 | deviance=8.6411E+6
# Iteration: 13 | deviance=8.6371E+6
# Iteration: 14 | deviance=8.6336E+6
# Iteration: 15 | deviance=8.6307E+6
# Iteration: 16 | deviance=8.6281E+6
# Iteration: 17 | deviance=8.6258E+6
# Iteration: 18 | deviance=8.6238E+6
# Iteration: 19 | deviance=8.6220E+6
# Iteration: 20 | deviance=8.6205E+6
# Iteration: 21 | deviance=8.6190E+6
# Iteration: 22 | deviance=8.6178E+6
# Iteration: 23 | deviance=8.6166E+6
# Iteration: 24 | deviance=8.6156E+6
# Iteration: 25 | deviance=8.6146E+6
# ...
