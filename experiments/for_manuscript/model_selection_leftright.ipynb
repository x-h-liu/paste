# %%
import sys
sys.path.insert(0, '/n/fs/ragr-research/users/xinhao/workspace/code/paste')


import scanpy as sc

from src.paste.fractional_model_selection import decide_overlap_plotting

# %load_ext autoreload
# %autoreload 2

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151507/twopieces_lr/151507_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151508/twopieces_lr/151508_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2821E+7
# Iteration: 1 | deviance=1.2821E+7
# Iteration: 2 | deviance=1.2184E+7
# Iteration: 3 | deviance=1.1837E+7
# Iteration: 4 | deviance=1.1677E+7
# Iteration: 5 | deviance=1.1600E+7
# Iteration: 6 | deviance=1.1558E+7
# Iteration: 7 | deviance=1.1532E+7
# Iteration: 8 | deviance=1.1513E+7
# Iteration: 9 | deviance=1.1498E+7
# Iteration: 10 | deviance=1.1486E+7
# Iteration: 11 | deviance=1.1476E+7
# Iteration: 12 | deviance=1.1468E+7
# Iteration: 13 | deviance=1.1460E+7
# Iteration: 14 | deviance=1.1454E+7
# Iteration: 15 | deviance=1.1448E+7
# Iteration: 16 | deviance=1.1443E+7
# Iteration: 17 | deviance=1.1438E+7
# Iteration: 18 | deviance=1.1434E+7
# Iteration: 19 | deviance=1.1430E+7
# Iteration: 20 | deviance=1.1427E+7
# Iteration: 21 | deviance=1.1424E+7
# Iteration: 22 | deviance=1.1421E+7
# Iteration: 23 | deviance=1.1418E+7
# Iteration: 24 | deviance=1.1416E+7
# Iteration: 25 | deviance=1.1414E+7
# Iteration: 26 | deviance=1.1412E+7
# Iteration: 27 | deviance=1.1410E+7
# Iteration: 28 | deviance=1.1408E+7
# Iteration: 29 | deviance=1.1406E+7
# Iteration: 30 | deviance=1.1404E+7
# Iteration: 31 | deviance=1.1403E+7
# Iteration: 32 | deviance=1.1402E+7
# Iteration: 33 | deviance=1.1400E+7
# Iteration: 34 | deviance=1.1399E+7
# Iteration: 35 | deviance=1.1398E+7
# Iteration: 36 | deviance=1.1396E+7
# GLM-PCA finished with joint matrix shape (6921, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151508/twopieces_lr/151508_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151509/twopieces_lr/151509_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3592E+7
# Iteration: 1 | deviance=1.3592E+7
# Iteration: 2 | deviance=1.2774E+7
# Iteration: 3 | deviance=1.2431E+7
# Iteration: 4 | deviance=1.2281E+7
# Iteration: 5 | deviance=1.2204E+7
# Iteration: 6 | deviance=1.2162E+7
# Iteration: 7 | deviance=1.2135E+7
# Iteration: 8 | deviance=1.2117E+7
# Iteration: 9 | deviance=1.2102E+7
# Iteration: 10 | deviance=1.2090E+7
# Iteration: 11 | deviance=1.2080E+7
# Iteration: 12 | deviance=1.2071E+7
# Iteration: 13 | deviance=1.2064E+7
# Iteration: 14 | deviance=1.2057E+7
# Iteration: 15 | deviance=1.2051E+7
# Iteration: 16 | deviance=1.2046E+7
# Iteration: 17 | deviance=1.2041E+7
# Iteration: 18 | deviance=1.2037E+7
# Iteration: 19 | deviance=1.2033E+7
# Iteration: 20 | deviance=1.2030E+7
# Iteration: 21 | deviance=1.2027E+7
# Iteration: 22 | deviance=1.2024E+7
# Iteration: 23 | deviance=1.2021E+7
# Iteration: 24 | deviance=1.2019E+7
# Iteration: 25 | deviance=1.2016E+7
# Iteration: 26 | deviance=1.2014E+7
# Iteration: 27 | deviance=1.2012E+7
# Iteration: 28 | deviance=1.2010E+7
# Iteration: 29 | deviance=1.2009E+7
# Iteration: 30 | deviance=1.2007E+7
# Iteration: 31 | deviance=1.2005E+7
# Iteration: 32 | deviance=1.2004E+7
# Iteration: 33 | deviance=1.2002E+7
# Iteration: 34 | deviance=1.2001E+7
# Iteration: 35 | deviance=1.2000E+7
# GLM-PCA finished with joint matrix shape (7285, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151509/twopieces_lr/151509_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151510/twopieces_lr/151510_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3982E+7
# Iteration: 1 | deviance=1.3982E+7
# Iteration: 2 | deviance=1.3214E+7
# Iteration: 3 | deviance=1.2887E+7
# Iteration: 4 | deviance=1.2730E+7
# Iteration: 5 | deviance=1.2654E+7
# Iteration: 6 | deviance=1.2612E+7
# Iteration: 7 | deviance=1.2586E+7
# Iteration: 8 | deviance=1.2567E+7
# Iteration: 9 | deviance=1.2553E+7
# Iteration: 10 | deviance=1.2540E+7
# Iteration: 11 | deviance=1.2530E+7
# Iteration: 12 | deviance=1.2521E+7
# Iteration: 13 | deviance=1.2513E+7
# Iteration: 14 | deviance=1.2506E+7
# Iteration: 15 | deviance=1.2500E+7
# Iteration: 16 | deviance=1.2494E+7
# Iteration: 17 | deviance=1.2489E+7
# Iteration: 18 | deviance=1.2485E+7
# Iteration: 19 | deviance=1.2481E+7
# Iteration: 20 | deviance=1.2477E+7
# Iteration: 21 | deviance=1.2473E+7
# Iteration: 22 | deviance=1.2470E+7
# Iteration: 23 | deviance=1.2467E+7
# Iteration: 24 | deviance=1.2464E+7
# Iteration: 25 | deviance=1.2462E+7
# Iteration: 26 | deviance=1.2459E+7
# Iteration: 27 | deviance=1.2457E+7
# Iteration: 28 | deviance=1.2455E+7
# Iteration: 29 | deviance=1.2453E+7
# Iteration: 30 | deviance=1.2451E+7
# Iteration: 31 | deviance=1.2450E+7
# Iteration: 32 | deviance=1.2448E+7
# Iteration: 33 | deviance=1.2447E+7
# Iteration: 34 | deviance=1.2445E+7
# Iteration: 35 | deviance=1.2444E+7
# GLM-PCA finished with joint matrix shape (7294, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151669/twopieces_lr/151669_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151670/twopieces_lr/151670_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.1783E+7
# Iteration: 1 | deviance=1.1783E+7
# Iteration: 2 | deviance=1.1235E+7
# Iteration: 3 | deviance=1.0931E+7
# Iteration: 4 | deviance=1.0781E+7
# Iteration: 5 | deviance=1.0717E+7
# Iteration: 6 | deviance=1.0685E+7
# Iteration: 7 | deviance=1.0665E+7
# Iteration: 8 | deviance=1.0651E+7
# Iteration: 9 | deviance=1.0640E+7
# Iteration: 10 | deviance=1.0631E+7
# Iteration: 11 | deviance=1.0624E+7
# Iteration: 12 | deviance=1.0618E+7
# Iteration: 13 | deviance=1.0612E+7
# Iteration: 14 | deviance=1.0608E+7
# Iteration: 15 | deviance=1.0604E+7
# Iteration: 16 | deviance=1.0600E+7
# Iteration: 17 | deviance=1.0597E+7
# Iteration: 18 | deviance=1.0594E+7
# Iteration: 19 | deviance=1.0592E+7
# Iteration: 20 | deviance=1.0590E+7
# Iteration: 21 | deviance=1.0588E+7
# Iteration: 22 | deviance=1.0586E+7
# Iteration: 23 | deviance=1.0584E+7
# Iteration: 24 | deviance=1.0583E+7
# Iteration: 25 | deviance=1.0581E+7
# Iteration: 26 | deviance=1.0580E+7
# Iteration: 27 | deviance=1.0579E+7
# Iteration: 28 | deviance=1.0578E+7
# GLM-PCA finished with joint matrix shape (5708, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.7

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151670/twopieces_lr/151670_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151671/twopieces_lr/151671_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2173E+7
# Iteration: 1 | deviance=1.2172E+7
# Iteration: 2 | deviance=1.1572E+7
# Iteration: 3 | deviance=1.1249E+7
# Iteration: 4 | deviance=1.1101E+7
# Iteration: 5 | deviance=1.1035E+7
# Iteration: 6 | deviance=1.1002E+7
# Iteration: 7 | deviance=1.0981E+7
# Iteration: 8 | deviance=1.0965E+7
# Iteration: 9 | deviance=1.0953E+7
# Iteration: 10 | deviance=1.0943E+7
# Iteration: 11 | deviance=1.0934E+7
# Iteration: 12 | deviance=1.0927E+7
# Iteration: 13 | deviance=1.0921E+7
# Iteration: 14 | deviance=1.0915E+7
# Iteration: 15 | deviance=1.0911E+7
# Iteration: 16 | deviance=1.0906E+7
# Iteration: 17 | deviance=1.0903E+7
# Iteration: 18 | deviance=1.0899E+7
# Iteration: 19 | deviance=1.0896E+7
# Iteration: 20 | deviance=1.0894E+7
# Iteration: 21 | deviance=1.0891E+7
# Iteration: 22 | deviance=1.0889E+7
# Iteration: 23 | deviance=1.0887E+7
# Iteration: 24 | deviance=1.0885E+7
# Iteration: 25 | deviance=1.0883E+7
# Iteration: 26 | deviance=1.0882E+7
# Iteration: 27 | deviance=1.0881E+7
# Iteration: 28 | deviance=1.0879E+7
# Iteration: 29 | deviance=1.0878E+7
# GLM-PCA finished with joint matrix shape (5946, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.4

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151671/twopieces_lr/151671_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151672/twopieces_lr/151672_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2752E+7
# Iteration: 1 | deviance=1.2751E+7
# Iteration: 2 | deviance=1.2054E+7
# Iteration: 3 | deviance=1.1729E+7
# Iteration: 4 | deviance=1.1583E+7
# Iteration: 5 | deviance=1.1515E+7
# Iteration: 6 | deviance=1.1480E+7
# Iteration: 7 | deviance=1.1457E+7
# Iteration: 8 | deviance=1.1441E+7
# Iteration: 9 | deviance=1.1429E+7
# Iteration: 10 | deviance=1.1419E+7
# Iteration: 11 | deviance=1.1411E+7
# Iteration: 12 | deviance=1.1405E+7
# Iteration: 13 | deviance=1.1399E+7
# Iteration: 14 | deviance=1.1394E+7
# Iteration: 15 | deviance=1.1390E+7
# Iteration: 16 | deviance=1.1386E+7
# Iteration: 17 | deviance=1.1383E+7
# Iteration: 18 | deviance=1.1380E+7
# Iteration: 19 | deviance=1.1377E+7
# Iteration: 20 | deviance=1.1375E+7
# Iteration: 21 | deviance=1.1373E+7
# Iteration: 22 | deviance=1.1371E+7
# Iteration: 23 | deviance=1.1369E+7
# Iteration: 24 | deviance=1.1368E+7
# Iteration: 25 | deviance=1.1366E+7
# Iteration: 26 | deviance=1.1365E+7
# Iteration: 27 | deviance=1.1364E+7
# GLM-PCA finished with joint matrix shape (6212, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151673/twopieces_lr/151673_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151674/twopieces_lr/151674_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3992E+7
# Iteration: 1 | deviance=1.3991E+7
# Iteration: 2 | deviance=1.2313E+7
# Iteration: 3 | deviance=1.1966E+7
# Iteration: 4 | deviance=1.1817E+7
# Iteration: 5 | deviance=1.1743E+7
# Iteration: 6 | deviance=1.1704E+7
# Iteration: 7 | deviance=1.1679E+7
# Iteration: 8 | deviance=1.1662E+7
# Iteration: 9 | deviance=1.1649E+7
# Iteration: 10 | deviance=1.1639E+7
# Iteration: 11 | deviance=1.1631E+7
# Iteration: 12 | deviance=1.1625E+7
# Iteration: 13 | deviance=1.1619E+7
# Iteration: 14 | deviance=1.1614E+7
# Iteration: 15 | deviance=1.1610E+7
# Iteration: 16 | deviance=1.1607E+7
# Iteration: 17 | deviance=1.1604E+7
# Iteration: 18 | deviance=1.1601E+7
# Iteration: 19 | deviance=1.1599E+7
# Iteration: 20 | deviance=1.1597E+7
# Iteration: 21 | deviance=1.1595E+7
# Iteration: 22 | deviance=1.1593E+7
# Iteration: 23 | deviance=1.1592E+7
# Iteration: 24 | deviance=1.1590E+7
# Iteration: 25 | deviance=1.1589E+7
# Iteration: 26 | deviance=1.1588E+7
# GLM-PCA finished with joint matrix shape (5806, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.8

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151674/twopieces_lr/151674_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151675/twopieces_lr/151675_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3224E+7
# Iteration: 1 | deviance=1.3222E+7
# Iteration: 2 | deviance=1.1784E+7
# Iteration: 3 | deviance=1.1469E+7
# Iteration: 4 | deviance=1.1325E+7
# Iteration: 5 | deviance=1.1250E+7
# Iteration: 6 | deviance=1.1206E+7
# Iteration: 7 | deviance=1.1179E+7
# Iteration: 8 | deviance=1.1161E+7
# Iteration: 9 | deviance=1.1148E+7
# Iteration: 10 | deviance=1.1138E+7
# Iteration: 11 | deviance=1.1130E+7
# Iteration: 12 | deviance=1.1123E+7
# Iteration: 13 | deviance=1.1118E+7
# Iteration: 14 | deviance=1.1113E+7
# Iteration: 15 | deviance=1.1109E+7
# Iteration: 16 | deviance=1.1105E+7
# Iteration: 17 | deviance=1.1102E+7
# Iteration: 18 | deviance=1.1099E+7
# Iteration: 19 | deviance=1.1096E+7
# Iteration: 20 | deviance=1.1094E+7
# Iteration: 21 | deviance=1.1092E+7
# Iteration: 22 | deviance=1.1090E+7
# Iteration: 23 | deviance=1.1089E+7
# Iteration: 24 | deviance=1.1087E+7
# Iteration: 25 | deviance=1.1086E+7
# Iteration: 26 | deviance=1.1085E+7
# Iteration: 27 | deviance=1.1083E+7
# GLM-PCA finished with joint matrix shape (5750, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.6

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151675/twopieces_lr/151675_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151676/twopieces_lr/151676_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col1.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2106E+7
# Iteration: 1 | deviance=1.2106E+7
# Iteration: 2 | deviance=1.0952E+7
# Iteration: 3 | deviance=1.0637E+7
# Iteration: 4 | deviance=1.0501E+7
# Iteration: 5 | deviance=1.0439E+7
# Iteration: 6 | deviance=1.0406E+7
# Iteration: 7 | deviance=1.0386E+7
# Iteration: 8 | deviance=1.0371E+7
# Iteration: 9 | deviance=1.0360E+7
# Iteration: 10 | deviance=1.0351E+7
# Iteration: 11 | deviance=1.0343E+7
# Iteration: 12 | deviance=1.0337E+7
# Iteration: 13 | deviance=1.0332E+7
# Iteration: 14 | deviance=1.0327E+7
# Iteration: 15 | deviance=1.0323E+7
# Iteration: 16 | deviance=1.0320E+7
# Iteration: 17 | deviance=1.0317E+7
# Iteration: 18 | deviance=1.0314E+7
# Iteration: 19 | deviance=1.0312E+7
# Iteration: 20 | deviance=1.0310E+7
# Iteration: 21 | deviance=1.0308E+7
# Iteration: 22 | deviance=1.0306E+7
# Iteration: 23 | deviance=1.0304E+7
# Iteration: 24 | deviance=1.0303E+7
# Iteration: 25 | deviance=1.0302E+7
# Iteration: 26 | deviance=1.0300E+7
# Iteration: 27 | deviance=1.0299E+7
# Iteration: 28 | deviance=1.0298E+7
# GLM-PCA finished with joint matrix shape (5574, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.8
