# %%
import sys
sys.path.insert(0, '/n/fs/ragr-research/users/xinhao/workspace/code/paste')


import scanpy as sc

from src.paste.fractional_model_selection import decide_overlap_plotting

# %load_ext autoreload
# %autoreload 2

# %%
"""
Patient 1, AB
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151507/twopieces/151507_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151508/twopieces/151508_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2849E+7
# Iteration: 1 | deviance=1.2849E+7
# Iteration: 2 | deviance=1.2260E+7
# Iteration: 3 | deviance=1.1886E+7
# Iteration: 4 | deviance=1.1740E+7
# Iteration: 5 | deviance=1.1674E+7
# Iteration: 6 | deviance=1.1638E+7
# Iteration: 7 | deviance=1.1615E+7
# Iteration: 8 | deviance=1.1597E+7
# Iteration: 9 | deviance=1.1584E+7
# Iteration: 10 | deviance=1.1572E+7
# Iteration: 11 | deviance=1.1563E+7
# Iteration: 12 | deviance=1.1555E+7
# Iteration: 13 | deviance=1.1548E+7
# Iteration: 14 | deviance=1.1542E+7
# Iteration: 15 | deviance=1.1536E+7
# Iteration: 16 | deviance=1.1531E+7
# Iteration: 17 | deviance=1.1527E+7
# Iteration: 18 | deviance=1.1523E+7
# Iteration: 19 | deviance=1.1520E+7
# Iteration: 20 | deviance=1.1516E+7
# Iteration: 21 | deviance=1.1513E+7
# Iteration: 22 | deviance=1.1511E+7
# Iteration: 23 | deviance=1.1508E+7
# Iteration: 24 | deviance=1.1506E+7
# Iteration: 25 | deviance=1.1504E+7
# Iteration: 26 | deviance=1.1502E+7
# Iteration: 27 | deviance=1.1500E+7
# Iteration: 28 | deviance=1.1498E+7
# Iteration: 29 | deviance=1.1497E+7
# Iteration: 30 | deviance=1.1495E+7
# Iteration: 31 | deviance=1.1494E+7
# Iteration: 32 | deviance=1.1493E+7
# Iteration: 33 | deviance=1.1491E+7
# Iteration: 34 | deviance=1.1490E+7
# GLM-PCA finished with joint matrix shape (6867, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
"""
Patient 1, BC
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151508/twopieces/151508_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151509/twopieces/151509_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3185E+7
# Iteration: 1 | deviance=1.3185E+7
# Iteration: 2 | deviance=1.2562E+7
# Iteration: 3 | deviance=1.2208E+7
# Iteration: 4 | deviance=1.2055E+7
# Iteration: 5 | deviance=1.1979E+7
# Iteration: 6 | deviance=1.1940E+7
# Iteration: 7 | deviance=1.1914E+7
# Iteration: 8 | deviance=1.1895E+7
# Iteration: 9 | deviance=1.1880E+7
# Iteration: 10 | deviance=1.1868E+7
# Iteration: 11 | deviance=1.1858E+7
# Iteration: 12 | deviance=1.1850E+7
# Iteration: 13 | deviance=1.1843E+7
# Iteration: 14 | deviance=1.1837E+7
# Iteration: 15 | deviance=1.1831E+7
# Iteration: 16 | deviance=1.1826E+7
# Iteration: 17 | deviance=1.1821E+7
# Iteration: 18 | deviance=1.1817E+7
# Iteration: 19 | deviance=1.1814E+7
# Iteration: 20 | deviance=1.1810E+7
# Iteration: 21 | deviance=1.1807E+7
# Iteration: 22 | deviance=1.1804E+7
# Iteration: 23 | deviance=1.1801E+7
# Iteration: 24 | deviance=1.1799E+7
# Iteration: 25 | deviance=1.1796E+7
# Iteration: 26 | deviance=1.1794E+7
# Iteration: 27 | deviance=1.1792E+7
# Iteration: 28 | deviance=1.1790E+7
# Iteration: 29 | deviance=1.1789E+7
# Iteration: 30 | deviance=1.1787E+7
# Iteration: 31 | deviance=1.1786E+7
# Iteration: 32 | deviance=1.1784E+7
# Iteration: 33 | deviance=1.1783E+7
# Iteration: 34 | deviance=1.1781E+7
# Iteration: 35 | deviance=1.1780E+7
# GLM-PCA finished with joint matrix shape (7003, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.3

# %%
"""
Patient 1, CD
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151509/twopieces/151509_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151510/twopieces/151510_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.4329E+7
# Iteration: 1 | deviance=1.4329E+7
# Iteration: 2 | deviance=1.3566E+7
# Iteration: 3 | deviance=1.3217E+7
# Iteration: 4 | deviance=1.3067E+7
# Iteration: 5 | deviance=1.2997E+7
# Iteration: 6 | deviance=1.2959E+7
# Iteration: 7 | deviance=1.2934E+7
# Iteration: 8 | deviance=1.2916E+7
# Iteration: 9 | deviance=1.2901E+7
# Iteration: 10 | deviance=1.2889E+7
# Iteration: 11 | deviance=1.2879E+7
# Iteration: 12 | deviance=1.2870E+7
# Iteration: 13 | deviance=1.2862E+7
# Iteration: 14 | deviance=1.2856E+7
# Iteration: 15 | deviance=1.2850E+7
# Iteration: 16 | deviance=1.2844E+7
# Iteration: 17 | deviance=1.2839E+7
# Iteration: 18 | deviance=1.2835E+7
# Iteration: 19 | deviance=1.2831E+7
# Iteration: 20 | deviance=1.2827E+7
# Iteration: 21 | deviance=1.2824E+7
# Iteration: 22 | deviance=1.2820E+7
# Iteration: 23 | deviance=1.2817E+7
# Iteration: 24 | deviance=1.2815E+7
# Iteration: 25 | deviance=1.2812E+7
# Iteration: 26 | deviance=1.2810E+7
# Iteration: 27 | deviance=1.2807E+7
# Iteration: 28 | deviance=1.2805E+7
# Iteration: 29 | deviance=1.2803E+7
# Iteration: 30 | deviance=1.2802E+7
# Iteration: 31 | deviance=1.2800E+7
# Iteration: 32 | deviance=1.2798E+7
# Iteration: 33 | deviance=1.2797E+7
# Iteration: 34 | deviance=1.2795E+7
# Iteration: 35 | deviance=1.2794E+7
# Iteration: 36 | deviance=1.2792E+7
# GLM-PCA finished with joint matrix shape (7417, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.6

# %%
"""
Patient 2, AB
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151669/twopieces/151669_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151670/twopieces/151670_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.1861E+7
# Iteration: 1 | deviance=1.1860E+7
# Iteration: 2 | deviance=1.1314E+7
# Iteration: 3 | deviance=1.1017E+7
# Iteration: 4 | deviance=1.0870E+7
# Iteration: 5 | deviance=1.0804E+7
# Iteration: 6 | deviance=1.0772E+7
# Iteration: 7 | deviance=1.0752E+7
# Iteration: 8 | deviance=1.0737E+7
# Iteration: 9 | deviance=1.0726E+7
# Iteration: 10 | deviance=1.0717E+7
# Iteration: 11 | deviance=1.0710E+7
# Iteration: 12 | deviance=1.0704E+7
# Iteration: 13 | deviance=1.0699E+7
# Iteration: 14 | deviance=1.0695E+7
# Iteration: 15 | deviance=1.0691E+7
# Iteration: 16 | deviance=1.0688E+7
# Iteration: 17 | deviance=1.0685E+7
# Iteration: 18 | deviance=1.0682E+7
# Iteration: 19 | deviance=1.0680E+7
# Iteration: 20 | deviance=1.0678E+7
# Iteration: 21 | deviance=1.0676E+7
# Iteration: 22 | deviance=1.0674E+7
# Iteration: 23 | deviance=1.0672E+7
# Iteration: 24 | deviance=1.0671E+7
# Iteration: 25 | deviance=1.0670E+7
# Iteration: 26 | deviance=1.0668E+7
# Iteration: 27 | deviance=1.0667E+7
# Iteration: 28 | deviance=1.0666E+7
# GLM-PCA finished with joint matrix shape (5802, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.5

# %%
"""
Patient 2, BC
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151670/twopieces/151670_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151671/twopieces/151671_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2950E+7
# Iteration: 1 | deviance=1.2949E+7
# Iteration: 2 | deviance=1.2337E+7
# Iteration: 3 | deviance=1.2009E+7
# Iteration: 4 | deviance=1.1851E+7
# Iteration: 5 | deviance=1.1781E+7
# Iteration: 6 | deviance=1.1745E+7
# Iteration: 7 | deviance=1.1723E+7
# Iteration: 8 | deviance=1.1708E+7
# Iteration: 9 | deviance=1.1697E+7
# Iteration: 10 | deviance=1.1688E+7
# Iteration: 11 | deviance=1.1681E+7
# Iteration: 12 | deviance=1.1675E+7
# Iteration: 13 | deviance=1.1669E+7
# Iteration: 14 | deviance=1.1665E+7
# Iteration: 15 | deviance=1.1661E+7
# Iteration: 16 | deviance=1.1658E+7
# Iteration: 17 | deviance=1.1655E+7
# Iteration: 18 | deviance=1.1652E+7
# Iteration: 19 | deviance=1.1650E+7
# Iteration: 20 | deviance=1.1648E+7
# Iteration: 21 | deviance=1.1646E+7
# Iteration: 22 | deviance=1.1644E+7
# Iteration: 23 | deviance=1.1643E+7
# Iteration: 24 | deviance=1.1641E+7
# Iteration: 25 | deviance=1.1640E+7
# GLM-PCA finished with joint matrix shape (6122, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.3

# %%
"""
Patient 2, CD
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151671/twopieces/151671_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151672/twopieces/151672_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3223E+7
# Iteration: 1 | deviance=1.3223E+7
# Iteration: 2 | deviance=1.2529E+7
# Iteration: 3 | deviance=1.2208E+7
# Iteration: 4 | deviance=1.2059E+7
# Iteration: 5 | deviance=1.1995E+7
# Iteration: 6 | deviance=1.1962E+7
# Iteration: 7 | deviance=1.1940E+7
# Iteration: 8 | deviance=1.1925E+7
# Iteration: 9 | deviance=1.1913E+7
# Iteration: 10 | deviance=1.1904E+7
# Iteration: 11 | deviance=1.1896E+7
# Iteration: 12 | deviance=1.1889E+7
# Iteration: 13 | deviance=1.1884E+7
# Iteration: 14 | deviance=1.1879E+7
# Iteration: 15 | deviance=1.1875E+7
# Iteration: 16 | deviance=1.1871E+7
# Iteration: 17 | deviance=1.1868E+7
# Iteration: 18 | deviance=1.1865E+7
# Iteration: 19 | deviance=1.1863E+7
# Iteration: 20 | deviance=1.1860E+7
# Iteration: 21 | deviance=1.1858E+7
# Iteration: 22 | deviance=1.1856E+7
# Iteration: 23 | deviance=1.1855E+7
# Iteration: 24 | deviance=1.1853E+7
# Iteration: 25 | deviance=1.1852E+7
# Iteration: 26 | deviance=1.1850E+7
# Iteration: 27 | deviance=1.1849E+7
# GLM-PCA finished with joint matrix shape (6230, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.7

# %%
"""
Patient 3, AB
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151673/twopieces/151673_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151674/twopieces/151674_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3983E+7
# Iteration: 1 | deviance=1.3981E+7
# Iteration: 2 | deviance=1.2274E+7
# Iteration: 3 | deviance=1.1953E+7
# Iteration: 4 | deviance=1.1811E+7
# Iteration: 5 | deviance=1.1737E+7
# Iteration: 6 | deviance=1.1696E+7
# Iteration: 7 | deviance=1.1668E+7
# Iteration: 8 | deviance=1.1648E+7
# Iteration: 9 | deviance=1.1633E+7
# Iteration: 10 | deviance=1.1622E+7
# Iteration: 11 | deviance=1.1613E+7
# Iteration: 12 | deviance=1.1606E+7
# Iteration: 13 | deviance=1.1600E+7
# Iteration: 14 | deviance=1.1595E+7
# Iteration: 15 | deviance=1.1591E+7
# Iteration: 16 | deviance=1.1587E+7
# Iteration: 17 | deviance=1.1584E+7
# Iteration: 18 | deviance=1.1581E+7
# Iteration: 19 | deviance=1.1578E+7
# Iteration: 20 | deviance=1.1576E+7
# Iteration: 21 | deviance=1.1573E+7
# Iteration: 22 | deviance=1.1572E+7
# Iteration: 23 | deviance=1.1570E+7
# Iteration: 24 | deviance=1.1568E+7
# Iteration: 25 | deviance=1.1567E+7
# Iteration: 26 | deviance=1.1565E+7
# Iteration: 27 | deviance=1.1564E+7
# GLM-PCA finished with joint matrix shape (5749, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.8

# %%
"""
Patient 3, BC
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151674/twopieces/151674_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151675/twopieces/151675_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.3199E+7
# Iteration: 1 | deviance=1.3197E+7
# Iteration: 2 | deviance=1.1688E+7
# Iteration: 3 | deviance=1.1379E+7
# Iteration: 4 | deviance=1.1234E+7
# Iteration: 5 | deviance=1.1159E+7
# Iteration: 6 | deviance=1.1117E+7
# Iteration: 7 | deviance=1.1092E+7
# Iteration: 8 | deviance=1.1074E+7
# Iteration: 9 | deviance=1.1062E+7
# Iteration: 10 | deviance=1.1052E+7
# Iteration: 11 | deviance=1.1044E+7
# Iteration: 12 | deviance=1.1037E+7
# Iteration: 13 | deviance=1.1032E+7
# Iteration: 14 | deviance=1.1027E+7
# Iteration: 15 | deviance=1.1023E+7
# Iteration: 16 | deviance=1.1020E+7
# Iteration: 17 | deviance=1.1016E+7
# Iteration: 18 | deviance=1.1014E+7
# Iteration: 19 | deviance=1.1011E+7
# Iteration: 20 | deviance=1.1009E+7
# Iteration: 21 | deviance=1.1007E+7
# Iteration: 22 | deviance=1.1006E+7
# Iteration: 23 | deviance=1.1004E+7
# Iteration: 24 | deviance=1.1003E+7
# Iteration: 25 | deviance=1.1002E+7
# Iteration: 26 | deviance=1.1000E+7
# GLM-PCA finished with joint matrix shape (5646, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.2

# %%
"""
Patient 3, CD
"""

# %%
sliceA_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151675/twopieces/151675_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row0_col0.h5ad'
sliceB_filename = '/n/fs/ragr-data/users/xinhao/DLPFC/sim/151676/twopieces/151676_overlap0.7_dropFalse_rotateFalse_resampleFalse_delta0_row1_col0.h5ad'
sliceA = sc.read_h5ad(sliceA_filename)
sliceB = sc.read_h5ad(sliceB_filename)
print(decide_overlap_plotting(sliceA, sliceB))
# Out:
# Starting GLM-PCA...
# Iteration: 0 | deviance=1.2111E+7
# Iteration: 1 | deviance=1.2111E+7
# Iteration: 2 | deviance=1.1024E+7
# Iteration: 3 | deviance=1.0698E+7
# Iteration: 4 | deviance=1.0562E+7
# Iteration: 5 | deviance=1.0505E+7
# Iteration: 6 | deviance=1.0475E+7
# Iteration: 7 | deviance=1.0455E+7
# Iteration: 8 | deviance=1.0440E+7
# Iteration: 9 | deviance=1.0429E+7
# Iteration: 10 | deviance=1.0421E+7
# Iteration: 11 | deviance=1.0414E+7
# Iteration: 12 | deviance=1.0408E+7
# Iteration: 13 | deviance=1.0403E+7
# Iteration: 14 | deviance=1.0398E+7
# Iteration: 15 | deviance=1.0395E+7
# Iteration: 16 | deviance=1.0391E+7
# Iteration: 17 | deviance=1.0388E+7
# Iteration: 18 | deviance=1.0386E+7
# Iteration: 19 | deviance=1.0384E+7
# Iteration: 20 | deviance=1.0381E+7
# Iteration: 21 | deviance=1.0380E+7
# Iteration: 22 | deviance=1.0378E+7
# Iteration: 23 | deviance=1.0376E+7
# Iteration: 24 | deviance=1.0375E+7
# Iteration: 25 | deviance=1.0374E+7
# Iteration: 26 | deviance=1.0372E+7
# Iteration: 27 | deviance=1.0371E+7
# GLM-PCA finished with joint matrix shape (5553, 50)
# 0.99
# 0.95
# 0.9
# 0.85
# 0.8
# 0.75
# 0.7
# 0.65
# 0.6
# 0.55
# 0.5
# 0.45
# 0.4
# 0.35
# 0.3
# 0.25
# 0.2
# 0.15
# 0.1
# 0.05
# 0.1
